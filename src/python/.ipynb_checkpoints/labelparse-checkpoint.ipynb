# %%
# Remove all mentions of blouse_DF and sunderas before writing to CSV, directly after making dataframe
# Another approach is to remove the JSON files of everything not MORIA.... and the MIROA with blouse_DF etc.
import json
import pandas as pd
from pandas.io.json import json_normalize 
from pandasql import sqldf
import os
from os import listdir
from os.path import isfile, join
DATAPATH = "../../data/Datasets_Enhancy/Annotation/"
IMAGEPATH = "../../data/Datasets_Enhancy/datasets/"

onlyfiles = [f for f in listdir(DATAPATH) if isfile(join(DATAPATH, f))]
ret = []
for f in onlyfiles:
    if ("MIROA") in f and not ("blouse" in f or "sudaderas" in f or "top_DF" in f):
        ret.append(f)
print(ret)
frames =[]
for i in range(len(ret)):
    with open(DATAPATH + ret[i]) as f:
        d = json.load(f)
        frames.append(pd.json_normalize(d['annotations']))
        
df = pd.concat(frames)
cols = [x for x in df.columns if "attributes" in x]
df["attributes"] = "-1"
df["attributes"] = df["attributes.Col"] + ", " + df["attributes.Categorie_de_vetement"]
df
#exportDf = df[["image_id", "attributes.Forme"]]
#exportDf = exportDf[exportDf["image_id"].str.contains("blouse_DF") == False]
#exportDf = exportDf[exportDf["image_id"].str.contains("top_DF") == False]
#exportDf = exportDf[exportDf["image_id"].str.contains("sudaderas") == False]
# Out:
# ['MIROA_Hauts_Anorak_Bomber_DF_Complet.json', 'MIROA_Full_body_petos_complet.json', 'MIROA_Full_body_monos_complet.json', 'MIROA_Bas_jeans_complet_retravailJBN.json', 'MIROA_Hauts_Blazer_DF_Complet.json', 'MIROA_Full_body_vestidos_complet.json', 'MIROA_Hauts_cardigans_complet.json', 'MIROA_Bas_faldas_complet.json', 'MIROA_Hauts_camisas_y_blusas_complet.json', 'MIROA_Hauts_jerseys_complet.json', 'MIROA_Full_body_jacket_DF_complet.json', 'MIROA_Full_Body_Romper_DF_Complet.json', 'MIROA_Full_body_abrigos_complet.json', 'MIROA_Full_body_coat_DF_complet.json', 'MIROA_Full_Body_jumpsuit_DF_Complet.json']
#         id                                           image_id  category_id  \
# 0        0  anorak_bomber_DF/Hooded_Cotton_Canvas_Anorak/i...            0
# 1        1  anorak_bomber_DF/Hooded_Cotton_Canvas_Anorak/i...            0
# 2        2  anorak_bomber_DF/Hooded_Cotton_Canvas_Anorak/i...            0
# 3        3  anorak_bomber_DF/Hooded_Cotton_Canvas_Anorak/i...            0
# 4        4  anorak_bomber_DF/Hooded_Cotton_Canvas_Anorak/i...            0
# ...    ...                                                ...          ...
# 3561  3561  jumpsuit_DF/Woven_Ruffle_Cami_Jumpsuit/img_000...            0
# 3562  3562  jumpsuit_DF/Zippered_Colorblock_Crepe_Jumpsuit...            0
# 3563  3563  jumpsuit_DF/Zippered_Colorblock_Crepe_Jumpsuit...            0
# 3564  3564  jumpsuit_DF/Zippered_Colorblock_Crepe_Jumpsuit...            0
# 3565  3565      jumpsuit_DF/Utility_Jumpsuit/img_00000021.jpg            0
#
#                                         segmentation     area  \
# 0               [[34, 5, 279, 5, 279, 299, 34, 299]]    72030
# 1       [[231, 348, 982, 348, 982, 1361, 231, 1361]]   760763
# 2             [[53, 51, 254, 51, 254, 299, 53, 299]]    49848
# 3         [[116, 132, 478, 132, 478, 689, 116, 689]]   201634
# 4     [[281, 516, 1668, 516, 1668, 2234, 281, 2234]]  2382866
# ...                                              ...      ...
# 3561    [[352, 201, 661, 201, 661, 1321, 352, 1321]]   346080
# 3562          [[99, 46, 202, 46, 202, 281, 99, 281]]    24205
# 3563          [[90, 46, 197, 46, 197, 362, 90, 362]]    33812
# 3564        [[100, 41, 187, 41, 187, 265, 100, 265]]    19488
# 3565  [[778, 971, 1420, 971, 1420, 2609, 778, 2609]]  1051596
#
#                         bbox  iscrowd attributes.Col  \
# 0          [34, 5, 245, 294]        0           Null
# 1      [231, 348, 751, 1013]        0           Null
# 2         [53, 51, 201, 248]        0           Null
# 3       [116, 132, 362, 557]        0           Null
# 4     [281, 516, 1387, 1718]        0  Col_Classique
# ...                      ...      ...            ...
# 3561   [352, 201, 309, 1120]        0           Null
# 3562      [99, 46, 103, 235]        0           Null
# 3563      [90, 46, 107, 316]        0           Null
# 3564      [100, 41, 87, 224]        0           Null
# 3565   [778, 971, 642, 1638]        0  Col_Classique
#
#                 attributes.Motifs  \
# 0                             Uni
# 1                             Uni
# 2                             Uni
# 3                             Uni
# 4     Serigraphie_Et_Illustration
# ...                           ...
# 3561                          Uni
# 3562                          Uni
# 3563              Bi_Ou_Tri_Color
# 3564                          Uni
# 3565                          Uni
#
#                                      attributes.Details  ...  \
# 0                           [Col_Fourrure_Ou_Imitation]  ...
# 1     [Boutons, Zip_Et_Fermeture_Eclair_Stylistique,...  ...
# 2                                     [Boutons, Poches]  ...
# 3     [Zip_Et_Fermeture_Eclair_Stylistique, Poches, ...  ...
# 4                                              [Poches]  ...
# ...                                                 ...  ...
# 3561                                             [Null]  ...
# 3562                                             [Null]  ...
# 3563                                             [Null]  ...
# 3564                                             [Null]  ...
# 3565                                           [Poches]  ...
#
#      attributes.Epaules_Denudees attributes.Categorie_de_vetement  \
# 0                           Null                            Parka
# 1                           Null          Veste_Urbaine_Et_Casual
# 2                           Null                            Parka
# 3                           Null                          Manteau
# 4                           Null              Tops_Matiere_Droite
# ...                          ...                              ...
# 3561                         NaN                      Combinaison
# 3562                         NaN                      Combinaison
# 3563                         NaN                      Combinaison
# 3564                         NaN                        Salopette
# 3565                        Null                      Combinaison
#
#      attributes.Coupe attributes.Manches_Originales attributes.Forme  \
# 0                 NaN                           NaN              NaN
# 1                 NaN                           NaN              NaN
# 2                 NaN                           NaN              NaN
# 3                 NaN                           NaN              NaN
# 4        Coupe_Droite                          Null              NaN
# ...               ...                           ...              ...
# 3561     Coupe_Droite                          Null              NaN
# 3562     Coupe_Droite                          Null              NaN
# 3563     Coupe_Droite                          Null              NaN
# 3564     Coupe_Droite                           NaN              NaN
# 3565     Coupe_Droite                          Null              NaN
#
#      attributes.Occasion attributes.Taille_Hanches  \
# 0                    NaN                       NaN
# 1                    NaN                       NaN
# 2                    NaN                       NaN
# 3                    NaN                       NaN
# 4                    NaN                       NaN
# ...                  ...                       ...
# 3561                 NaN                       NaN
# 3562                 NaN                       NaN
# 3563                 NaN                       NaN
# 3564                 NaN                       NaN
# 3565                 NaN                       NaN
#
#      attributes.Motifs_Imprimes_Taille attributes.Motifs_Imprimes_Niveau_2  \
# 0                                  NaN                                 NaN
# 1                                  NaN                                 NaN
# 2                                  NaN                                 NaN
# 3                                  NaN                                 NaN
# 4                                  NaN                                 NaN
# ...                                ...                                 ...
# 3561                               NaN                                 NaN
# 3562                               NaN                                 NaN
# 3563                               NaN                                 NaN
# 3564                               NaN                                 NaN
# 3565                               NaN                                 NaN
#
#      attributes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 3561        NaN
# 3562        NaN
# 3563        NaN
# 3564        NaN
# 3565        NaN
#
# [54461 rows x 24 columns]

# %%
deleted = 0
changed = 0
s = len(exportDf.index)
outPut = exportDf.copy()

for i in range(s):
    id = exportDf.image_id.iloc[i]
    path1 = IMAGEPATH + id
    path2 = IMAGEPATH + "dataset/" + id
    relPath1 =  id
    relPath2 = "dataset/" + id
    
    if not os.path.isfile(path1):
        if not os.path.isfile(path2):
            try:
                idx = outPut.loc[outPut['image_id'] == id].index[0]
                print("DROPPED AT idx {} path {}".format(i, path2))
                outPut = outPut.drop(idx, axis = 0)
                deleted += 1
            except:
                print("ALREADY DROPPED {}".format(path2))
            
newLen = len(outPut.index)
for i in range(newLen):
    id = outPut.image_id.iloc[i]
    if os.path.isfile(IMAGEPATH + "dataset/" + id):
        outPut.loc[outPut['image_id'] == id, "image_id"] = "dataset/" + id



print("Total: {}".format(s))    
print("Deleted: {}".format(deleted))
print("Edited: {}".format(changed))
#outPut.to_csv(r'./export_data.csv', index = False)
outPut
# Out:
# ['MIROA_Hauts_Anorak_Bomber_DF_Complet.json', 'MIROA_Full_body_petos_complet.json', 'MIROA_Full_body_monos_complet.json', 'MIROA_Bas_jeans_complet_retravailJBN.json', 'MIROA_Hauts_Blazer_DF_Complet.json', 'MIROA_Full_body_vestidos_complet.json', 'MIROA_Hauts_cardigans_complet.json', 'MIROA_Bas_faldas_complet.json', 'MIROA_Hauts_camisas_y_blusas_complet.json', 'MIROA_Hauts_jerseys_complet.json', 'MIROA_Full_body_jacket_DF_complet.json', 'MIROA_Full_Body_Romper_DF_Complet.json', 'MIROA_Full_body_abrigos_complet.json', 'MIROA_Full_body_coat_DF_complet.json', 'MIROA_Full_Body_jumpsuit_DF_Complet.json']
# DROPPED AT idx 6816 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Boxy_Buttoned_Blazer/img_00000052.jpg
# DROPPED AT idx 6817 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Boxy_Buttoned_Blazer/img_00000052.jpg
# DROPPED AT idx 6826 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Boxy_Buttoned_Blazer/img_00000071.jpg
# DROPPED AT idx 6849 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Button-Front_Blazer/img_00000004.jpg
# DROPPED AT idx 6919 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Button-Front_Blazer/img_00000102.jpg
# DROPPED AT idx 7036 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Classic_Boyfriend_Blazer/img_00000112.jpg
# DROPPED AT idx 7086 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Classic_Cuffed_Blazer/img_00000043.jpg
# DROPPED AT idx 7087 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Classic_Cuffed_Blazer/img_00000043.jpg
# DROPPED AT idx 7090 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Classic_Cuffed_Blazer/img_00000048.jpg
# DROPPED AT idx 7515 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Classic_Two-Button_Blazer/img_00000108.jpg
# DROPPED AT idx 7895 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Collarless_Open-Front_Blazer/img_00000043.jpg
# DROPPED AT idx 7896 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Collarless_Open-Front_Blazer/img_00000043.jpg
# DROPPED AT idx 8273 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Cuffed_Knit_Blazer/img_00000062.jpg
# DROPPED AT idx 8292 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Cuffed_Knit_Blazer/img_00000085.jpg
# DROPPED AT idx 8293 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Cuffed_Knit_Blazer/img_00000085.jpg
# DROPPED AT idx 8294 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Cuffed_Knit_Blazer/img_00000085.jpg
# DROPPED AT idx 8319 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Cuffed_Knit_Blazer/img_00000110.jpg
# DROPPED AT idx 8445 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Cuffed-Sleeve_Knit_Blazer/img_00000065.jpg
# DROPPED AT idx 8447 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Cuffed-Sleeve_Knit_Blazer/img_00000080.jpg
# DROPPED AT idx 8448 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Cuffed-Sleeve_Knit_Blazer/img_00000080.jpg
# DROPPED AT idx 8471 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Double-Breasted_Blazer/img_00000030.jpg
# DROPPED AT idx 8472 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Double-Breasted_Blazer/img_00000030.jpg
# DROPPED AT idx 8516 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Double-Breasted_Blazer/img_00000069.jpg
# DROPPED AT idx 8517 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Double-Breasted_Blazer/img_00000069.jpg
# DROPPED AT idx 8759 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Dropped-Collar_Blazer/img_00000057.jpg
# DROPPED AT idx 8793 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Dropped_Lapel_Chiffon-Sleeved_Blazer/img_00000007.jpg
# DROPPED AT idx 8794 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Dropped_Lapel_Chiffon-Sleeved_Blazer/img_00000007.jpg
# DROPPED AT idx 8802 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Dropped_Lapel_Chiffon-Sleeved_Blazer/img_00000037.jpg
# DROPPED AT idx 8850 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Faux_Leather_Shawl_Collar_Blazer/img_00000008.jpg
# DROPPED AT idx 8851 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Faux_Leather_Shawl_Collar_Blazer/img_00000008.jpg
# DROPPED AT idx 8863 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Faux_Leather_Shawl_Collar_Blazer/img_00000033.jpg
# DROPPED AT idx 9034 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Flat_Collar_Blazer/img_00000017.jpg
# DROPPED AT idx 9048 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Flat_Collar_Blazer/img_00000058.jpg
# DROPPED AT idx 9062 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Flat_Collar_Blazer/img_00000083.jpg
# DROPPED AT idx 9063 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Flat_Collar_Blazer/img_00000083.jpg
# DROPPED AT idx 9093 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Floral_and_Bird_Print_Blazer/img_00000060.jpg
# DROPPED AT idx 9106 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Floral_and_Bird_Print_Blazer/img_00000086.jpg
# DROPPED AT idx 9107 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Floral_and_Bird_Print_Blazer/img_00000086.jpg
# DROPPED AT idx 9108 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Floral_and_Bird_Print_Blazer/img_00000086.jpg
# DROPPED AT idx 9109 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Floral_and_Bird_Print_Blazer/img_00000086.jpg
# DROPPED AT idx 9308 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Glen_Plaid_Blazer/img_00000049.jpg
# DROPPED AT idx 9456 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Longline_Boyfriend_Blazer/img_00000016.jpg
# DROPPED AT idx 9457 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Longline_Boyfriend_Blazer/img_00000016.jpg
# DROPPED AT idx 9458 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Longline_Boyfriend_Blazer/img_00000016.jpg
# DROPPED AT idx 9459 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Longline_Boyfriend_Blazer/img_00000016.jpg
# DROPPED AT idx 9460 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Longline_Boyfriend_Blazer/img_00000016.jpg
# DROPPED AT idx 9749 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Longline_Slit_Blazer/img_00000066.jpg
# DROPPED AT idx 9750 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Longline_Slit_Blazer/img_00000066.jpg
# DROPPED AT idx 9768 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Must-Have_Ruched_Blazer/img_00000017.jpg
# DROPPED AT idx 9875 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Must-Have_Ruched_Blazer/img_00000138.jpg
# DROPPED AT idx 9894 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Notched_Open-Front_Textured_Blazer/img_00000017.jpg
# DROPPED AT idx 10013 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Open-Front_Linen_Blazer/img_00000065.jpg
# DROPPED AT idx 10260 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Oversized_Two-Tone_Blazer/img_00000007.jpg
# DROPPED AT idx 10261 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Oversized_Two-Tone_Blazer/img_00000007.jpg
# ALREADY DROPPED ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Oversized_Two-Tone_Blazer/img_00000016.jpg
# DROPPED AT idx 10266 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Oversized_Two-Tone_Blazer/img_00000016.jpg
# DROPPED AT idx 10283 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Oversized_Two-Tone_Blazer/img_00000035.jpg
# DROPPED AT idx 10284 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Oversized_Two-Tone_Blazer/img_00000035.jpg
# DROPPED AT idx 10285 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Oversized_Two-Tone_Blazer/img_00000035.jpg
# DROPPED AT idx 10286 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Oversized_Two-Tone_Blazer/img_00000035.jpg
# DROPPED AT idx 11476 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Tuxedo-Inspired_Blazer/img_00000035.jpg
# DROPPED AT idx 11477 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Tuxedo-Inspired_Blazer/img_00000035.jpg
# DROPPED AT idx 11478 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Tuxedo-Inspired_Blazer/img_00000035.jpg
# DROPPED AT idx 11479 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Tuxedo-Inspired_Blazer/img_00000035.jpg
# DROPPED AT idx 11480 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Tuxedo-Inspired_Blazer/img_00000035.jpg
# DROPPED AT idx 11508 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Tuxedo-Inspired_Blazer/img_00000071.jpg
# DROPPED AT idx 11509 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Tuxedo-Inspired_Blazer/img_00000071.jpg
# DROPPED AT idx 11510 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Tuxedo-Inspired_Blazer/img_00000071.jpg
# DROPPED AT idx 11533 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Tuxedo-Inspired_Blazer/img_00000083.jpg
# DROPPED AT idx 11534 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Tuxedo-Inspired_Blazer/img_00000083.jpg
# DROPPED AT idx 11535 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Tuxedo-Inspired_Blazer/img_00000083.jpg
# DROPPED AT idx 11740 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Two-Button_Blazer/img_00000105.jpg
# DROPPED AT idx 12005 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Zippered_Shawl_Collar_Blazer/img_00000052.jpg
# DROPPED AT idx 12006 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Zippered_Shawl_Collar_Blazer/img_00000052.jpg
# DROPPED AT idx 12052 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Zippered_Shawl_Collar_Blazer/img_00000107.jpg
# DROPPED AT idx 12110 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Zippered_Single-Button_Blazer/img_00000032.jpg
# DROPPED AT idx 12111 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Zippered_Single-Button_Blazer/img_00000032.jpg
# DROPPED AT idx 12444 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Watercolor_Floral_Print_Blazer/img_00000032.jpg
# DROPPED AT idx 12445 path ../../data/Datasets_Enhancy/datasets/dataset/blazer_DF/Watercolor_Floral_Print_Blazer/img_00000032.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 58>()
#      59     id = outPut.image_id.iloc[i]
#      60     if os.path.isfile(IMAGEPATH + "dataset/" + id):
# ---> 61         outPut.loc[outPut['image_id'] == id, "image_id"] = "dataset/" + id
#      65 print("Total: {}".format(s))
#      66 print("Deleted: {}".format(deleted))
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/ops/common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:5620, in Series._cmp_method(self, other, op)
#    5617 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    5619 with np.errstate(all="ignore"):
# -> 5620     res_values = ops.comparison_op(lvalues, rvalues, op)
#    5622 return self._construct_result(res_values, name=res_name)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:283, in comparison_op(left, right, op)
#     280     return invalid_comparison(lvalues, rvalues, op)
#     282 elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 283     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     285 else:
#     286     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:73, in comp_method_OBJECT_ARRAY(op, x, y)
#      71     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      72 else:
# ---> 73     result = libops.scalar_compare(x.ravel(), y, op)
#      74 return result.reshape(x.shape)
#
# KeyboardInterrupt:

# %%
outPut.to_csv(r'./export_data_working.csv', index = False)

# %%
# Out:
# 54451    NaN
# Name: segmentation, dtype: object

# %%
# Out:
#                                               image_id  \
# 353  anorak_bomber_DF/Hooded_Cotton_Canvas_Anorak/i...
# 354  anorak_bomber_DF/Hooded_Cotton_Canvas_Anorak/i...
# 355  anorak_bomber_DF/Hooded_Cotton_Canvas_Anorak/i...
# 356  anorak_bomber_DF/Hooded_Cotton_Canvas_Anorak/i...
# 357  anorak_bomber_DF/Hooded_Cotton_Canvas_Anorak/i...
# 358  anorak_bomber_DF/Quilted_Faux_Leather_Bomber/i...
# 359  anorak_bomber_DF/Quilted_Faux_Leather_Bomber/i...
# 360  anorak_bomber_DF/Zip_Collar_Bomber/img_0000002...
# 361  anorak_bomber_DF/Zip_Collar_Bomber/img_0000001...
# 362  anorak_bomber_DF/Zip_Collar_Bomber/img_0000003...
#
#                                        segmentation
# 353      [[227, 548, 505, 548, 505, 977, 227, 977]]
# 354        [[23, 109, 346, 109, 346, 544, 23, 544]]
# 355          [[64, 78, 289, 78, 289, 380, 64, 380]]
# 356          [[46, 81, 268, 81, 268, 466, 46, 466]]
# 357        [[29, 124, 356, 124, 356, 555, 29, 555]]
# 358        [[57, 172, 557, 172, 557, 838, 57, 838]]
# 359          [[73, 54, 229, 54, 229, 269, 73, 269]]
# 360        [[58, 113, 325, 113, 325, 409, 58, 409]]
# 361  [[131, 278, 1105, 278, 1105, 1343, 131, 1343]]
# 362          [[38, 50, 289, 50, 289, 381, 38, 381]]
