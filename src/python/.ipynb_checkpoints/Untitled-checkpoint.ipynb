# %%
import json
import pandas as pd
from pandas.io.json import json_normalize 

with open('../../data/dataset/Datasets_Enhancy/Annotation/MIROA_Hauts_blouse_DF_complet.json') as f:
    d = json.load(f)

table = pd.json_normalize(d['annotations'])
table.print()
# Out:
#           id                                           image_id  category_id  \
# 0          0  blouse_DF/Abstract_Daisy_Print_Blouse/img_0000...            0
# 1          1  blouse_DF/Abstract_Daisy_Print_Blouse/img_0000...            0
# 2          2  blouse_DF/Abstract_Daisy_Print_Blouse/img_0000...            0
# 3          3  blouse_DF/Abstract_Daisy_Print_Blouse/img_0000...            0
# 4          4  blouse_DF/Abstract_Daisy_Print_Blouse/img_0000...            0
# ...      ...                                                ...          ...
# 17631  17631  blouse_DF/Woven_Open-Back_Blouse/img_00000071.jpg            0
# 17632  17632  blouse_DF/Woven_Open-Back_Blouse/img_00000071.jpg            0
# 17633  17633  blouse_DF/Woven_Open-Back_Blouse/img_00000101.jpg            0
# 17634  17634  blouse_DF/Woven_Open-Back_Blouse/img_00000101.jpg            0
# 17635  17635  blouse_DF/Woven_Open-Back_Blouse/img_00000073.jpg            0
#
# ...
